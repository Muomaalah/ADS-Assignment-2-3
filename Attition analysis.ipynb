# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('ADS-Assignment-2-3-main/Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df_2 = df[['Age','Attrition','JobRole','DistanceFromHome']]

df_2
# Out:
#       Age Attrition                    JobRole  DistanceFromHome
# 0      41       Yes            Sales Executive                 1
# 1      49        No         Research Scientist                 8
# 2      37       Yes      Laboratory Technician                 2
# 3      33        No         Research Scientist                 3
# 4      27        No      Laboratory Technician                 2
# ...   ...       ...                        ...               ...
# 1465   36        No      Laboratory Technician                23
# 1466   39        No  Healthcare Representative                 6
# 1467   27        No     Manufacturing Director                 4
# 1468   49        No            Sales Executive                 2
# 1469   34        No      Laboratory Technician                 8
#
# [1470 rows x 4 columns]

# %%
pd.crosstab(df_2['Attrition'], df_2['JobRole'])
# Out:
# JobRole    Healthcare Representative  Human Resources  Laboratory Technician  \
# Attrition
# No                               122               40                    197
# Yes                                9               12                     62
#
# JobRole    Manager  Manufacturing Director  Research Director  \
# Attrition
# No              97                     135                 78
# Yes              5                      10                  2
#
# JobRole    Research Scientist  Sales Executive  Sales Representative
# Attrition
# No                        245              269                    50
# Yes                        47               57                    33

# %%
Job_Dist_Attr = df.pivot_table(values=["DistanceFromHome"], index=["Attrition", "JobRole"], aggfunc=np.mean).reset_index()

# %%
Job_Dist_Attr
# Out:
#    Attrition                    JobRole  DistanceFromHome
# 0         No  Healthcare Representative          9.204918
# 1         No            Human Resources          6.600000
# 2         No      Laboratory Technician          9.329949
# 3         No                    Manager          7.927835
# 4         No     Manufacturing Director          9.533333
# 5         No          Research Director          8.474359
# 6         No         Research Scientist          8.869388
# 7         No            Sales Executive          9.026022
# 8         No       Sales Representative          9.000000
# 9        Yes  Healthcare Representative         17.666667
# 10       Yes            Human Resources         13.416667
# 11       Yes      Laboratory Technician          9.661290
# 12       Yes                    Manager         10.000000
# 13       Yes     Manufacturing Director          8.800000
# 14       Yes          Research Director          7.000000
# ...

# %%
import seaborn as sns

plt.style.use('seaborn-bright')

plt.figure(figsize=(15,8))

plt.xticks(rotation=90)

sns.barplot(data = Job_Dist_Attr, x= 'JobRole', y= 'DistanceFromHome', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='DistanceFromHome'>

# %%
income_edu = df.pivot_table(values=["MonthlyIncome"], index=["Attrition", "EducationField"], aggfunc=np.mean).reset_index()

# %%
income_edu
# Out:
#    Attrition    EducationField  MonthlyIncome
# 0         No   Human Resources    8579.950000
# 1         No     Life Sciences    6775.437137
# 2         No         Marketing    7569.774194
# 3         No           Medical    6800.805486
# 4         No             Other    6422.704225
# 5         No  Technical Degree    6284.810000
# 6        Yes   Human Resources    3416.000000
# 7        Yes     Life Sciences    4650.022472
# 8        Yes         Marketing    6564.942857
# 9        Yes           Medical    4659.269841
# 10       Yes             Other    3805.000000
# 11       Yes  Technical Degree    4112.968750

# %%
import seaborn as sns

plt.style.use('seaborn-bright')

plt.figure(figsize=(15,8))

plt.xticks(rotation=90)

sns.barplot(data = income_edu, x= 'EducationField', y= 'MonthlyIncome', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='MonthlyIncome'>
